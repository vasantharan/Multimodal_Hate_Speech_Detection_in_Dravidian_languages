# %% [markdown]
# TAMIL using *bert-base-multilingual-cased*

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from transformers import AutoTokenizer, AutoModel
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization,Bidirectional,Lambda,LSTM,Embedding,Conv1D,MaxPooling1D,GlobalMaxPooling1D,LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting advertools
#   Downloading advertools-0.16.4-py2.py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.5.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: pyasn1>=0.4 in /usr/local/lib/python3.10/dist-packages (from advertools) (0.6.1)
# Collecting scrapy>=2.5.0 (from advertools)
#   Downloading Scrapy-2.12.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting twython>=3.8.0 (from advertools)
#   Downloading twython-3.9.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from advertools) (17.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Collecting Twisted>=21.7.0 (from scrapy>=2.5.0->advertools)
#   Downloading twisted-24.11.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy>=2.5.0->advertools) (43.0.3)
# Collecting cssselect>=0.9.1 (from scrapy>=2.5.0->advertools)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting itemloaders>=1.0.1 (from scrapy>=2.5.0->advertools)
#   Downloading itemloaders-1.3.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting parsel>=1.5.0 (from scrapy>=2.5.0->advertools)
#   Downloading parsel-1.9.1-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy>=2.5.0->advertools) (24.2.1)
# Collecting queuelib>=1.4.2 (from scrapy>=2.5.0->advertools)
#   Downloading queuelib-1.7.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting service-identity>=18.1.0 (from scrapy>=2.5.0->advertools)
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting w3lib>=1.17.0 (from scrapy>=2.5.0->advertools)
#   Downloading w3lib-2.2.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting zope.interface>=5.1.0 (from scrapy>=2.5.0->advertools)
#   Downloading zope.interface-7.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.1 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy>=2.5.0->advertools)
#   Downloading Protego-0.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting itemadapter>=0.1.0 (from scrapy>=2.5.0->advertools)
#   Downloading itemadapter-0.10.0-py3-none-any.whl.metadata (18 kB)
# Collecting tldextract (from scrapy>=2.5.0->advertools)
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from scrapy>=2.5.0->advertools) (5.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from scrapy>=2.5.0->advertools) (0.7.1)
# Collecting PyDispatcher>=2.0.5 (from scrapy>=2.5.0->advertools)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from twython>=3.8.0->advertools) (1.3.1)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (8.1.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=37.0.0->scrapy>=2.5.0->advertools) (1.17.1)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy>=2.5.0->advertools)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.4.0->twython>=3.8.0->advertools) (3.2.2)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy>=2.5.0->advertools) (24.3.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy>=2.5.0->advertools) (0.4.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.5)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: tomli>=2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.1)
# Collecting automat>=24.8.0 (from Twisted>=21.7.0->scrapy>=2.5.0->advertools)
#   Downloading Automat-24.8.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting constantly>=15.1 (from Twisted>=21.7.0->scrapy>=2.5.0->advertools)
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting hyperlink>=17.1.1 (from Twisted>=21.7.0->scrapy>=2.5.0->advertools)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting incremental>=24.7.0 (from Twisted>=21.7.0->scrapy>=2.5.0->advertools)
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface>=5.1.0->scrapy>=2.5.0->advertools) (75.1.0)
# Collecting requests-file>=1.4 (from tldextract->scrapy>=2.5.0->advertools)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy>=2.5.0->advertools) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.4 MB/s eta 0:00:00
# Downloading advertools-0.16.4-py2.py3-none-any.whl (408 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.7/408.7 kB 10.5 MB/s eta 0:00:00
# Downloading Scrapy-2.12.0-py2.py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 12.6 MB/s eta 0:00:00
# Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 21.8 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading itemadapter-0.10.0-py3-none-any.whl (11 kB)
# Downloading itemloaders-1.3.2-py3-none-any.whl (12 kB)
# Downloading parsel-1.9.1-py2.py3-none-any.whl (17 kB)
# Downloading Protego-0.3.1-py2.py3-none-any.whl (8.5 kB)
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading queuelib-1.7.0-py2.py3-none-any.whl (13 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 8.1 MB/s eta 0:00:00
# Downloading twisted-24.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 29.1 MB/s eta 0:00:00
# Downloading w3lib-2.2.1-py3-none-any.whl (21 kB)
# Downloading zope.interface-7.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.5/254.5 kB 15.5 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 4.4 MB/s eta 0:00:00
# Downloading Automat-24.8.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.3 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 4.1 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Installing collected packages: PyDispatcher, morfessor, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, incremental, hyperlink, cssselect, constantly, automat, Twisted, requests-file, parsel, twython, tldextract, sphinxcontrib-jquery, sphinx-argparse, service-identity, itemloaders, sphinx-rtd-theme, scrapy, indic-nlp-library, advertools
# Successfully installed PyDispatcher-2.0.7 Twisted-24.11.0 advertools-0.16.4 automat-24.8.1 constantly-23.10.4 cssselect-1.2.0 hyperlink-21.0.0 incremental-24.7.2 indic-nlp-library-0.92 itemadapter-0.10.0 itemloaders-1.3.2 jmespath-1.0.1 morfessor-2.0.6 parsel-1.9.1 protego-0.3.1 queuelib-1.7.0 requests-file-2.1.0 scrapy-2.12.0 service-identity-24.2.0 sphinx-argparse-0.5.2 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1 tldextract-5.1.3 twython-3.9.1 w3lib-2.2.1 zope.interface-7.2

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
def load_dataset(base_dir='/content', lang='tamil'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TA-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_df = load_dataset()
# Out:
# Using device: cpu

# %%
dataset_df
# Out:
#     audio_path                                         transcript class_label  \
# 0          Nil  உருவத்தை வச்ச ஒருத்தன் கிண்டல் பண்றான் பாருங்க...           C
# 1          Nil  காமெடி பண்ண சொன்னா ஒருத்தன உருவ கேலி பண்ணிட்டு...           C
# 2          Nil  இந்த உருவத்தை வைத்து கிண்டல் கேலி பண்ணி சிரிக்...           C
# 3          Nil  புரிஞ்சுக்கணும் மேடையில் ஒரு நாகரிகம்னு ஒன்னு ...           C
# 4          Nil  என்னா மல மல அண்ணாமலை இது உலகத்தோட ஸ்டைலு உட்கா...           C
# ..         ...                                                ...         ...
# 509        Nil  கேவலப்படுத்த அசிங்கப்படுது அவமானப்படுறது இதெல்...           C
# 510        Nil  ஏலே உன் மூஞ்சி மொகரையும் பாரு இல்லையே குற்றாலத...           C
# 511        Nil  மிகப்பெரிய தவறு  விஜய் பனி இருக்கான் நிச்சயம் ...           C
# 512        Nil  ஏண்டா அயோக்கிய ராஸ்கல் நீ தூக்கிட்டு போவியா டா...           C
# 513        Nil  பச்சங்கள் வந்து செக்ஸ்தான் பெரிது, அதுதான் ஆம்...           G
#
#       gender
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# 509  Unknown
# 510  Unknown
# 511  Unknown
# 512  Unknown
# 513  Unknown
#
# [514 rows x 4 columns]

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['tamil']))
def preprocess_tamil_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ta")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ta"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_df['cleaned_transcript'] = dataset_df['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_df['encoded_label'] = label_encoder.fit_transform(dataset_df['class_label'])
label_encoder_path = "tamil_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
# Out:
# Label encoder saved to tamil_label_encoder.pkl

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
def extract_embeddings(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
            encoded_inputs = {key: tensor.to(device) for key, tensor in encoded_inputs.items()}
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
X_train_embeddings = extract_embeddings("bert-base-multilingual-cased", X_train.tolist())
X_test_embeddings = extract_embeddings("bert-base-multilingual-cased", X_test.tolist())
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_embeddings.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(
    X_train_embeddings, y_train_cat,
    validation_data=(X_test_embeddings, y_test_cat),
    epochs=35, batch_size=32)
loss, accuracy = model.evaluate(X_test_embeddings, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_embeddings)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_33"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_114 (Dense)                    │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_67               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_75 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_115 (Dense)                    │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_68               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_76 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_116 (Dense)                    │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 231,941 (906.02 KB)
#  Trainable params: 231,173 (903.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.2157 - loss: 2.5983 - val_accuracy: 0.5534 - val_loss: 1.2992
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.3703 - loss: 1.9612 - val_accuracy: 0.5340 - val_loss: 1.2921
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4463 - loss: 1.7244 - val_accuracy: 0.6214 - val_loss: 1.2317
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.5070 - loss: 1.5253 - val_accuracy: 0.5922 - val_loss: 1.1970
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.
    preprocessed_text = preprocess_tamil_text(input_text)
    embedding = extract_embeddings("bert-base-multilingual-cased", [preprocessed_text])
    prediction = loaded_model.predict(embedding)
    predicted_label_index = np.argmax(prediction)
    predicted_label = label_encoder.inverse_transform([predicted_label_index])[0]
    print(f"Input Text: {input_text}")
    print(f"Predicted Label: {predicted_label}")
    return predicted_label
new_text ="மற்ற மதங்களை ஆதரிக்கிறவர்கள் எல்லாம் துரோகிகள்."
predicted_label = test_model(new_text)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as 'tamil_classification_model.h5'
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# Input Text: மற்ற மதங்களை ஆதரிக்கிறவர்கள் எல்லாம் துரோகிகள்.
# Predicted Label: R

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel
from tensorflow.keras.models import load_model
import pickle
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
stopwords = list(sorted(adv.stopwords['tamil']))
def preprocess_tamil_text(text):
    """Preprocess Tamil text."""
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ta"))
    tokens = [token for token in tokens if token not in stopwords]
    processed_text = ' '.join(tokens)
    return processed_text
def extract_embeddings(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
test_file_path = '/content/TA-AT-test.xlsx'  
test_data = pd.read_excel(test_file_path)
test_data['cleaned_transcript'] = test_data['Transcript'].apply(preprocess_tamil_text)
bert_model_name = "bert-base-multilingual-cased"
test_embeddings = extract_embeddings(bert_model_name, test_data['cleaned_transcript'].tolist())
trained_model_path = "/content/tamil_classification_model.h5"  
trained_model = load_model(trained_model_path)
label_encoder_path = "/content/tamil_label_encoder.pkl"  
with open(label_encoder_path, "rb") as f:
    label_encoder = pickle.load(f)
predictions = trained_model.predict(test_embeddings)
predicted_labels = label_encoder.inverse_transform(np.argmax(predictions, axis=1))
test_data['Predicted_Class'] = predicted_labels
output_file_path = './TA-AT-test-predictions.xlsx'
test_data.to_excel(output_file_path, index=False)
print(f"Predictions saved to: {output_file_path}")
# Out:
# Device: cpu
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predictions saved to: ./TA-AT-test-predictions.xlsx

# %% [markdown]
# TELUGU using *bert-base-multilingual-cased*

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
def load_dataset(base_dir='/content', lang='tel'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TE-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"} 
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dft = load_dataset()
# Out:
# Using device: cpu

# %%
dataset_dft
# Out:
#     audio_path                                         transcript class_label  \
# 0          Nil  ఈ కాలంలో మీరు ఒకసారి ఒబ్సర్వ్ చేయండి మన స్టేటు...           R
# 1          Nil  హిందూ థర్మాన్ని ఎవరేమన్నా కూడా వాడికొచ్చే ఒకేఒ...           R
# 2          Nil  ఒక ముస్లింనిగాని. ఒక్క నిమిషం భార్గవి కల్యాణిగ...           R
# 3          Nil  ఈ సెక్యులర్ ఇండియా డెమోక్రాటిక్ ఇండియా అని మాట...           R
# 4          Nil  హిందువులున్న ఈ భారతదేశంలో ,ఈ భారతదేశంలో , సనాత...           R
# ..         ...                                                ...         ...
# 551        Nil  బాగుండటం అంటే బాగా ఉండటం కాదత్తా నలుగురితో ఉండ...           N
# 552        Nil  దేవుడు డెఫినిషన్ అర్ధమయిపోయింది బయ్యా ఆడు అక్క...           N
# 553        Nil  మనిషిని ప్రేమిస్తే అబధం విలువ తెలుస్తుంది కరెక...           N
# 554        Nil  ఇంకో విచిత్రం ఏంటంటే మన లైఫ్ ని ఇంటరెస్టింగ్ గ...           N
# 555        Nil  జీవితం అంటే ప్రోబ్ల్మ్స్  లేకుండా బతకడం కాదు ఉ...           N
#
#       gender
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# 551  Unknown
# 552  Unknown
# 553  Unknown
# 554  Unknown
# 555  Unknown
#
# [556 rows x 4 columns]

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['telugu']))
def preprocess_tel_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("te")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="te"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_dft['cleaned_transcript'] = dataset_dft['transcript'].apply(preprocess_tel_text)
label_encoder = LabelEncoder()
dataset_dft['encoded_label'] = label_encoder.fit_transform(dataset_dft['class_label'])
label_encoder_path = "tel_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
# Out:
# Label encoder saved to tel_label_encoder.pkl

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset_dft['cleaned_transcript'], dataset_dft['encoded_label'], test_size=0.2, random_state=42
)
def extract_embeddings(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
            encoded_inputs = {key: tensor.to(device) for key, tensor in encoded_inputs.items()}
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
X_train_embeddings = extract_embeddings("bert-base-multilingual-cased", X_train.tolist())
X_test_embeddings = extract_embeddings("bert-base-multilingual-cased", X_test.tolist())
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %%
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_embeddings.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(
    X_train_embeddings, y_train_cat,
    validation_data=(X_test_embeddings, y_test_cat),
    epochs=30, batch_size=32
)
loss, accuracy = model.evaluate(X_test_embeddings, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_embeddings)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 231,429 (904.02 KB)
#  Trainable params: 230,917 (902.02 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - accuracy: 0.2061 - loss: 2.7811 - val_accuracy: 0.3929 - val_loss: 1.4347
# Epoch 2/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4898 - loss: 1.5589 - val_accuracy: 0.4464 - val_loss: 1.3518
# Epoch 3/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4829 - loss: 1.4684 - val_accuracy: 0.4018 - val_loss: 1.3560
# Epoch 4/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5293 - loss: 1.2298 - val_accuracy: 0.4375 - val_loss: 1.3111
# Epoch 5/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5928 - loss: 1.1279 - val_accuracy: 0.4286 - val_loss: 1.2913
# Epoch 6/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6197 - loss: 0.9703 - val_accuracy: 0.4286 - val_loss: 1.2620
# Epoch 7/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5801 - loss: 0.9944 - val_accuracy: 0.4821 - val_loss: 1.2102
# Epoch 8/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6502 - loss: 0.9213 - val_accuracy: 0.5446 - val_loss: 1.1568
# Epoch 9/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7212 - loss: 0.7692 - val_accuracy: 0.5446 - val_loss: 1.1117
# Epoch 10/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6918 - loss: 0.7725 - val_accuracy: 0.5000 - val_loss: 1.1185
# Epoch 11/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7196 - loss: 0.7561 - val_accuracy: 0.6071 - val_loss: 1.0687
# Epoch 12/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7386 - loss: 0.6888 - val_accuracy: 0.5893 - val_loss: 1.1076
# Epoch 13/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7417 - loss: 0.6629 - val_accuracy: 0.5804 - val_loss: 1.0577
# Epoch 14/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8075 - loss: 0.5252 - val_accuracy: 0.6071 - val_loss: 1.0588
# Epoch 15/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7620 - loss: 0.5825 - val_accuracy: 0.5982 - val_loss: 1.0530
# Epoch 16/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7621 - loss: 0.5317 - val_accuracy: 0.6071 - val_loss: 0.9925
# Epoch 17/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7919 - loss: 0.5338 - val_accuracy: 0.6339 - val_loss: 0.9399
# Epoch 18/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8525 - loss: 0.4777 - val_accuracy: 0.6964 - val_loss: 0.9210
# Epoch 19/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8352 - loss: 0.4258 - val_accuracy: 0.6518 - val_loss: 0.9480
# Epoch 20/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8225 - loss: 0.4880 - val_accuracy: 0.6696 - val_loss: 0.9645
# Epoch 21/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8103 - loss: 0.5118 - val_accuracy: 0.6964 - val_loss: 0.9693
# Epoch 22/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8664 - loss: 0.4072 - val_accuracy: 0.6518 - val_loss: 0.9642
# Epoch 23/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8654 - loss: 0.3587 - val_accuracy: 0.6518 - val_loss: 0.9887
# Epoch 24/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8652 - loss: 0.3482 - val_accuracy: 0.6518 - val_loss: 1.0941
# Epoch 25/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8785 - loss: 0.3211 - val_accuracy: 0.6607 - val_loss: 1.0981
# Epoch 26/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9054 - loss: 0.3084 - val_accuracy: 0.6518 - val_loss: 1.0313
# Epoch 27/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9122 - loss: 0.2539 - val_accuracy: 0.6161 - val_loss: 1.0426
# Epoch 28/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8760 - loss: 0.3265 - val_accuracy: 0.6875 - val_loss: 1.0673
# Epoch 29/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9183 - loss: 0.2652 - val_accuracy: 0.6518 - val_loss: 1.0446
# Epoch 30/30
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9214 - loss: 0.2568 - val_accuracy: 0.7054 - val_loss: 1.0592
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7144 - loss: 1.0131
# Test Accuracy: 0.7054
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#               precision    recall  f1-score   support
#
#            C       0.85      0.77      0.81        22
#            G       0.56      0.65      0.60        23
#            N       0.67      0.72      0.69        36
#            P       0.80      0.89      0.84        18
#            R       0.83      0.38      0.53        13
#
#     accuracy                           0.71       112
#    macro avg       0.74      0.68      0.69       112
# weighted avg       0.72      0.71      0.70       112

# %%
from tensorflow.keras.models import load_model
model.save("tel_classification_model.h5")
print("Model saved as 'tel_classification_model.h5'")
def test_model(input_text, model_path="tel_classification_model.h5"):
    loaded_model = load_model(model_path)
    print("Model loaded successfully.")
    preprocessed_text = preprocess_tel_text(input_text)
    embedding = extract_embeddings("bert-base-multilingual-cased", [preprocessed_text])
    prediction = loaded_model.predict(embedding)
    predicted_label_index = np.argmax(prediction)
    predicted_label = label_encoder.inverse_transform([predicted_label_index])[0]
    print(f"Input Text: {input_text}")
    print(f"Predicted Label: {predicted_label}")
    return predicted_label
new_text ="మతంపై ప్రతికూల వ్యాఖ్యలు చేసిన వ్యక్తులు చట్టం ముందు తప్పించుకోలేరు."
predicted_label = test_model(new_text)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved as 'tel_classification_model.h5'
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Input Text: మతంపై ప్రతికూల వ్యాఖ్యలు చేసిన వ్యక్తులు చట్టం ముందు తప్పించుకోలేరు.
# Predicted Label: N

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel
from tensorflow.keras.models import load_model
import pickle
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
stopwords = list(sorted(adv.stopwords['telugu']))
def preprocess_Tel_text(text):
    """Preprocess Tamil text."""
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="te"))
    tokens = [token for token in tokens if token not in stopwords]
    processed_text = ' '.join(tokens)
    return processed_text
def extract_embeddings(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
test_file_path = '/content/TE-AT-test.xlsx'  
test_data = pd.read_excel(test_file_path)
test_data['cleaned_transcript'] = test_data['Transcript'].apply(preprocess_Tel_text)
bert_model_name = "bert-base-multilingual-cased"
test_embeddings = extract_embeddings(bert_model_name, test_data['cleaned_transcript'].tolist())
trained_model_path = "/content/tel_classification_model.h5"  
trained_model = load_model(trained_model_path)
label_encoder_path = "/content/tel_label_encoder.pkl"  
with open(label_encoder_path, "rb") as f:
    label_encoder = pickle.load(f)
predictions = trained_model.predict(test_embeddings)
predicted_labels = label_encoder.inverse_transform(np.argmax(predictions, axis=1))
test_data['Predicted_Class'] = predicted_labels
output_file_path = './tel-AT-test-predictions.xlsx'
test_data.to_excel(output_file_path, index=False)
print(f"Predictions saved to: {output_file_path}")
# Out:
# Device: cpu
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Predictions saved to: ./tel-AT-test-predictions.xlsx

# %% [markdown]
# MALAYALAM using *bert-base-multilingual-cased*

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
def load_dataset(base_dir='/content', lang='mal'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "ML-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dfm = load_dataset()
# Out:
# Using device: cpu

# %%
dataset_dfm
# Out:
#     audio_path                                         transcript class_label  \
# 0          Nil  നമസ്കാരം ഒരു ഒരു പരമ ചെറ്റയുടെ കാര്യമാണ് ഞാൻ പ...           C
# 1          Nil  ആദ്യം തന്നെ അവൻറെ ഐഡിയുടെ പേര് വരെ ഞാൻ ഇതിനകത്...           C
# 2          Nil               അവൻറെ ആ ചെറ്റയുടെ ആ പരമനാറിയുടെ പേര്           C
# 3          Nil  അവന്റെ ദുഷിച്ച മനസ്സ് കൊണ്ടുവന്ന് എൻറെ വീഡിയോയ...           C
# 4          Nil  നിൻറെ ദുഷിപ്പ് എല്ലാം എന്തിനാ എന്റെ നേർക്ക് തീ...           C
# ..         ...                                                ...         ...
# 878        Nil  ഒന്നിനെയും കൂടുതൽ ആശ്രയിക്കാതെ ഇരിക്കുക ഒരിക്ക...           N
# 879        Nil  പിന്തുടർച്ച ഇല്ലാത്ത പ്രവർത്തികൾക്ക് ഒന്നും യാ...           N
# 880        Nil  ഏറ്റവും അടുപ്പമുള്ളവരാണ് അതിസമർഥമായി ചതിക്കുന്...           N
# 881        Nil  സാഹചര്യം ഏതായാലും കീടങ്ങള് വേണ്ടയോ എന്ന് തീരുമ...           N
# 882        Nil  വെറുപ്പ് ശത്രു രോഗം ഇവയൊന്നുംതന്നെ ചെറുതായി കാ...           N
#
#       gender
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# 878  Unknown
# 879  Unknown
# 880  Unknown
# 881  Unknown
# 882  Unknown
#
# [883 rows x 4 columns]

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stop = [
    "അവൻ", "അവൾ", "അവർ", "ആ", "ആകാം", "ആകുന്നു", "ആകും", "ആകെയുള്ള", "ആകെയുള്ളത്", "ആകെയുള്ളവ", "ആകെയുള്ളവർ",
    "ആകെയുള്ളവൻ", "ആകെയുള്ളവൾ", "ആകെയുള്ളവൾക്ക്", "ആകുള്ളവൾക്ക്‌", "ഇത്", "ഇതിൽ", "ഇതിന്റെ", "ഇതും", "ഇതെല്ലാം",
    "ഇവ", "ഇവയിൽ", "ഇവയുടെ", "ഇവയും", "ഇവയെല്ലാം", "ഇവൻ", "ഇവൾ", "ഇവർ", "ഇവരുടെ", "ഇവരിൽ", "ഇവരെയും", "ഇവരെയെല്ലാം",
    "ഇവരോട്", "ഇവരോടും", "ഇവരോടുള്ള", "ഇവരോടുള്ളത്", "ഇവരോടുള്ളവ", "ഇവരോടുള്ളവർ", "ഇവരോടുള്ളവൻ", "ഇവരോടുള്ളവൾ",
    "ഇവരോടുള്ളവൾക്ക്", "ഇവരോടുള്ളവൾക്ക്‌"
]
def preprocess_malayalam_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ml")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ml"))
    tokens = [token for token in tokens if token not in stop]
    return ' '.join(tokens)
dataset_dfm['cleaned_transcript'] = dataset_dfm['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_dfm['encoded_label'] = label_encoder.fit_transform(dataset_dfm['class_label'])
label_encoder_path = "mal_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
# Out:
# Label encoder saved to mal_label_encoder.pkl

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset_dfm['cleaned_transcript'], dataset_dfm['encoded_label'], test_size=0.2, random_state=42
)
def extract_embeddings(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
            encoded_inputs = {key: tensor.to(device) for key, tensor in encoded_inputs.items()}
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
X_train_embeddings = extract_embeddings("bert-base-multilingual-cased", X_train.tolist())
X_test_embeddings = extract_embeddings("bert-base-multilingual-cased", X_test.tolist())

# %%
from tensorflow.keras.utils import to_categorical
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_embeddings.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(
    X_train_embeddings, y_train_cat,
    validation_data=(X_test_embeddings, y_test_cat),
    epochs=35, batch_size=32)
loss, accuracy = model.evaluate(X_test_embeddings, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_embeddings)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_49"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_162 (Dense)                    │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_91               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_107 (Dropout)                │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_163 (Dense)                    │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_108 (Dropout)                │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_164 (Dense)                    │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 231,429 (904.02 KB)
#  Trainable params: 230,917 (902.02 KB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.3351 - loss: 1.9655 - val_accuracy: 0.5537 - val_loss: 1.1763
# Epoch 2/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5937 - loss: 1.2021 - val_accuracy: 0.6158 - val_loss: 1.0844
# Epoch 3/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6901 - loss: 0.9284 - val_accuracy: 0.6102 - val_loss: 1.0266
# Epoch 4/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6917 - loss: 0.8747 - val_accuracy: 0.6441 - val_loss: 0.9980
# Epoch 5/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6844 - loss: 0.8500 - val_accuracy: 0.6667 - val_loss: 0.9372
# Epoch 6/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7612 - loss: 0.6474 - val_accuracy: 0.6836 - val_loss: 0.9334
# Epoch 7/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7616 - loss: 0.7263 - val_accuracy: 0.7062 - val_loss: 0.9132
# Epoch 8/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7723 - loss: 0.6603 - val_accuracy: 0.6949 - val_loss: 0.8543
# Epoch 9/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8213 - loss: 0.5353 - val_accuracy: 0.7175 - val_loss: 0.8905
# Epoch 10/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8225 - loss: 0.5301 - val_accuracy: 0.7232 - val_loss: 0.8772
# Epoch 11/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8427 - loss: 0.4380 - val_accuracy: 0.6667 - val_loss: 1.0447
# Epoch 12/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8172 - loss: 0.4907 - val_accuracy: 0.7401 - val_loss: 0.8897
# Epoch 13/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8269 - loss: 0.4760 - val_accuracy: 0.7175 - val_loss: 0.8667
# Epoch 14/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8192 - loss: 0.4380 - val_accuracy: 0.6949 - val_loss: 0.8958
# Epoch 15/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8615 - loss: 0.3896 - val_accuracy: 0.7288 - val_loss: 0.8498
# Epoch 16/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8251 - loss: 0.5056 - val_accuracy: 0.7175 - val_loss: 0.8499
# Epoch 17/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8631 - loss: 0.3950 - val_accuracy: 0.7232 - val_loss: 0.9052
# Epoch 18/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8748 - loss: 0.3790 - val_accuracy: 0.7119 - val_loss: 0.9373
# Epoch 19/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8632 - loss: 0.4140 - val_accuracy: 0.7345 - val_loss: 0.9608
# Epoch 20/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8817 - loss: 0.3530 - val_accuracy: 0.7175 - val_loss: 0.9563
# Epoch 21/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8747 - loss: 0.3527 - val_accuracy: 0.7232 - val_loss: 0.9764
# Epoch 22/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8729 - loss: 0.3233 - val_accuracy: 0.7458 - val_loss: 0.9792
# Epoch 23/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8736 - loss: 0.3406 - val_accuracy: 0.7401 - val_loss: 1.0379
# Epoch 24/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8831 - loss: 0.3365 - val_accuracy: 0.7288 - val_loss: 1.1577
# Epoch 25/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8818 - loss: 0.2970 - val_accuracy: 0.7062 - val_loss: 1.1319
# Epoch 26/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8769 - loss: 0.3458 - val_accuracy: 0.7062 - val_loss: 1.1402
# Epoch 27/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8884 - loss: 0.3070 - val_accuracy: 0.7062 - val_loss: 1.2197
# Epoch 28/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8739 - loss: 0.3460 - val_accuracy: 0.7288 - val_loss: 1.1268
# Epoch 29/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8970 - loss: 0.2855 - val_accuracy: 0.7232 - val_loss: 1.2162
# Epoch 30/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8735 - loss: 0.3243 - val_accuracy: 0.6836 - val_loss: 1.3715
# Epoch 31/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8894 - loss: 0.3077 - val_accuracy: 0.7175 - val_loss: 1.0611
# Epoch 32/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9288 - loss: 0.2123 - val_accuracy: 0.7345 - val_loss: 1.0898
# Epoch 33/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9335 - loss: 0.2265 - val_accuracy: 0.7232 - val_loss: 1.1141
# Epoch 34/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9303 - loss: 0.2109 - val_accuracy: 0.7175 - val_loss: 1.2019
# Epoch 35/35
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9196 - loss: 0.2256 - val_accuracy: 0.7288 - val_loss: 1.1187
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7299 - loss: 1.1468
# Test Accuracy: 0.7288
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#               precision    recall  f1-score   support
#
#            C       0.74      0.74      0.74        42
#            G       0.31      0.44      0.36         9
#            N       0.84      0.86      0.85        74
#            P       0.67      0.73      0.70        33
#            R       0.60      0.32      0.41        19
#
#     accuracy                           0.73       177
#    macro avg       0.63      0.62      0.61       177
# weighted avg       0.73      0.73      0.72       177

# %%
from tensorflow.keras.models import load_model
model.save("mal_classification_model.h5")
print("Model saved as 'mal_classification_model.h5'")
def test_model(input_text, model_path="mal_classification_model.h5"):
    loaded_model = load_model(model_path)
    print("Model loaded successfully.")
    preprocessed_text = preprocess_malayalam_text(input_text)
    embedding = extract_embeddings("bert-base-multilingual-cased", [preprocessed_text])
    prediction = loaded_model.predict(embedding)
    predicted_label_index = np.argmax(prediction)
    predicted_label = label_encoder.inverse_transform([predicted_label_index])[0]
    print(f"Input Text: {input_text}")
    print(f"Predicted Label: {predicted_label}")
    return predicted_label
new_text ="മതങ്ങൾ ഉൾപ്പെടെ എല്ലാവരും സമാധാനത്തിനായി പ്രവർത്തിക്കണം."
predicted_label = test_model(new_text)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model saved as 'mal_classification_model.h5'
# Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Input Text: മതങ്ങൾ ഉൾപ്പെടെ എല്ലാവരും സമാധാനത്തിനായി പ്രവർത്തിക്കണം.
# Predicted Label: N

# %%
import pandas as pd
import numpy as np
import torch
from transformers import AutoTokenizer, AutoModel
from tensorflow.keras.models import load_model
import pickle
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
stopwords = list(sorted(adv.stopwords['tamil']))
def preprocess_Mal_text(text):
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ta"))
    tokens = [token for token in tokens if token not in stopwords]
    processed_text = ' '.join(tokens)
    return processed_text
def extract_embeddings(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            encoded_inputs = tokenizer(batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt")
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
test_file_path = '/content/ML-AT-test.xlsx'  
test_data = pd.read_excel(test_file_path)
test_data['cleaned_transcript'] = test_data['Transcript'].apply(preprocess_Mal_text)
bert_model_name = "bert-base-multilingual-cased"
test_embeddings = extract_embeddings(bert_model_name, test_data['cleaned_transcript'].tolist())
trained_model_path = "/content/mal_classification_model.h5"  
trained_model = load_model(trained_model_path)
label_encoder_path = "/content/mal_label_encoder.pkl"  
with open(label_encoder_path, "rb") as f:
    label_encoder = pickle.load(f)
predictions = trained_model.predict(test_embeddings)
predicted_labels = label_encoder.inverse_transform(np.argmax(predictions, axis=1))
test_data['Predicted_Class'] = predicted_labels
output_file_path = './ml-AT-test-predictions.xlsx'
test_data.to_excel(output_file_path, index=False)
print(f"Predictions saved to: {output_file_path}")
# Out:
# Device: cpu
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Predictions saved to: ./ml-AT-test-predictions.xlsx

# %% [markdown]
# TAMIL Adding TFIDFVectorizer

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
def load_dataset(base_dir='/content', lang='tamil'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TA-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_df = load_dataset()
stopwords = list(sorted(adv.stopwords['tamil']))
def preprocess_tamil_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ta")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ta"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_df['cleaned_transcript'] = dataset_df['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_df['encoded_label'] = label_encoder.fit_transform(dataset_df['class_label'])
label_encoder_path = "tamil_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train).toarray()
X_test_tfidf = tfidf_vectorizer.transform(X_test).toarray()
print(f"TF-IDF Vectorized Train Data Shape: {X_train_tfidf.shape}")
print(f"TF-IDF Vectorized Test Data Shape: {X_test_tfidf.shape}")
model = Sequential([
    Dense(256, input_dim=X_train_tfidf.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
history = model.fit(
    X_train_tfidf, y_train_cat,
    validation_data=(X_test_tfidf, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_tfidf, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_tfidf)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: advertools in /usr/local/lib/python3.11/dist-packages (0.16.4)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (3.0.2)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: pyasn1>=0.4 in /usr/local/lib/python3.11/dist-packages (from advertools) (0.6.1)
# Requirement already satisfied: scrapy>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (2.12.0)
# Requirement already satisfied: twython>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (3.9.1)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (17.0.0)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->advertools) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->advertools) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->advertools) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.25.0->advertools) (2024.12.14)
# Requirement already satisfied: Twisted>=21.7.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.11.0)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (43.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.10.0)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (2.2.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (7.2)
# Requirement already satisfied: protego>=0.1.15 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (0.4.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.2)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (5.1.3)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (5.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (2.0.7)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from twython>=3.8.0->advertools) (1.3.1)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.1.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=37.0.0->scrapy>=2.5.0->advertools) (1.17.1)
# Requirement already satisfied: jmespath>=0.9.5 in /usr/local/lib/python3.11/dist-packages (from itemloaders>=1.0.1->scrapy>=2.5.0->advertools) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.4.0->twython>=3.8.0->advertools) (3.2.2)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy>=2.5.0->advertools) (24.3.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.11/dist-packages (from service-identity>=18.1.0->scrapy>=2.5.0->advertools) (0.4.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.5)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.18.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: automat>=24.8.0 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->scrapy>=2.5.0->advertools) (24.8.1)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->scrapy>=2.5.0->advertools) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->scrapy>=2.5.0->advertools) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->scrapy>=2.5.0->advertools) (24.7.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from Twisted>=21.7.0->scrapy>=2.5.0->advertools) (4.12.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from zope.interface>=5.1.0->scrapy>=2.5.0->advertools) (75.1.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy>=2.5.0->advertools) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract->scrapy>=2.5.0->advertools) (3.16.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=37.0.0->scrapy>=2.5.0->advertools) (2.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Label encoder saved to tamil_label_encoder.pkl
# TF-IDF Vectorized Train Data Shape: (411, 670)
# TF-IDF Vectorized Test Data Shape: (103, 670)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 256)                 │         171,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 206,853 (808.02 KB)
#  Trainable params: 206,085 (805.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.1994 - loss: 2.6964 - val_accuracy: 0.5631 - val_loss: 1.5463
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3313 - loss: 1.9941 - val_accuracy: 0.5631 - val_loss: 1.5084
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4344 - loss: 1.6703 - val_accuracy: 0.5631 - val_loss: 1.4702
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4945 - loss: 1.3898 - val_accuracy: 0.5631 - val_loss: 1.4325
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5644 - loss: 1.1251 - val_accuracy: 0.5631 - val_loss: 1.3975
# Epoch 6/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6137 - loss: 1.0332 - val_accuracy: 0.5631 - val_loss: 1.3597
# Epoch 7/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6928 - loss: 0.8124 - val_accuracy: 0.5631 - val_loss: 1.3243
# Epoch 8/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8212 - loss: 0.5257 - val_accuracy: 0.5631 - val_loss: 1.2960
# Epoch 9/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7970 - loss: 0.5351 - val_accuracy: 0.5631 - val_loss: 1.2696
# Epoch 10/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8413 - loss: 0.4579 - val_accuracy: 0.5631 - val_loss: 1.2495
# Epoch 11/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8450 - loss: 0.4304 - val_accuracy: 0.5631 - val_loss: 1.2335
# Epoch 12/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8808 - loss: 0.3479 - val_accuracy: 0.5631 - val_loss: 1.2251
# Epoch 13/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9170 - loss: 0.2834 - val_accuracy: 0.5631 - val_loss: 1.2198
# Epoch 14/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9217 - loss: 0.2679 - val_accuracy: 0.5631 - val_loss: 1.2168
# Epoch 15/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9116 - loss: 0.2198 - val_accuracy: 0.5631 - val_loss: 1.2142
# Epoch 16/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9432 - loss: 0.1705 - val_accuracy: 0.5631 - val_loss: 1.2115
# Epoch 17/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9478 - loss: 0.1688 - val_accuracy: 0.5631 - val_loss: 1.2158
# Epoch 18/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9398 - loss: 0.1663 - val_accuracy: 0.5631 - val_loss: 1.2188
# Epoch 19/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.1070 - val_accuracy: 0.5631 - val_loss: 1.2198
# Epoch 20/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9490 - loss: 0.1512 - val_accuracy: 0.5631 - val_loss: 1.2235
# Epoch 21/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9714 - loss: 0.0988 - val_accuracy: 0.5534 - val_loss: 1.2265
# Epoch 22/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9811 - loss: 0.0967 - val_accuracy: 0.5534 - val_loss: 1.2350
# Epoch 23/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9909 - loss: 0.0739 - val_accuracy: 0.5534 - val_loss: 1.2389
# Epoch 24/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9641 - loss: 0.1337 - val_accuracy: 0.5631 - val_loss: 1.2336
# Epoch 25/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9728 - loss: 0.1048 - val_accuracy: 0.5631 - val_loss: 1.2285
# Epoch 26/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9865 - loss: 0.0840 - val_accuracy: 0.5631 - val_loss: 1.2253
# Epoch 27/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9877 - loss: 0.0751 - val_accuracy: 0.5631 - val_loss: 1.2328
# Epoch 28/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9738 - loss: 0.1066 - val_accuracy: 0.5631 - val_loss: 1.2400
# Epoch 29/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9738 - loss: 0.0766 - val_accuracy: 0.5825 - val_loss: 1.2451
# Epoch 30/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9937 - loss: 0.0592 - val_accuracy: 0.5728 - val_loss: 1.2517
# Epoch 31/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9855 - loss: 0.0666 - val_accuracy: 0.5728 - val_loss: 1.2637
# Epoch 32/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9796 - loss: 0.0651 - val_accuracy: 0.5728 - val_loss: 1.2723
# Epoch 33/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9770 - loss: 0.0791 - val_accuracy: 0.5631 - val_loss: 1.2774
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9927 - loss: 0.0576 - val_accuracy: 0.5534 - val_loss: 1.2841
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.0350 - val_accuracy: 0.5534 - val_loss: 1.2928
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5589 - loss: 1.3023
# Test Accuracy: 0.5534
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#               precision    recall  f1-score   support
#
#            C       1.00      0.06      0.12        16
#            G       0.33      0.33      0.33         9
#            N       0.59      0.90      0.71        58
#            P       0.00      0.00      0.00         8
#            R       0.20      0.08      0.12        12
#
#     accuracy                           0.55       103
#    macro avg       0.42      0.28      0.26       103
# weighted avg       0.54      0.55      0.46       103
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# MALAYALAM Adding TFIDFVectorizer

# %%
def load_dataset(base_dir='/content', lang='mal'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "ML-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dfm = load_dataset()

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stop = [
    "അവൻ", "അവൾ", "അവർ", "ആ", "ആകാം", "ആകുന്നു", "ആകും", "ആകെയുള്ള", "ആകെയുള്ളത്", "ആകെയുള്ളവ", "ആകെയുള്ളവർ",
    "ആകെയുള്ളവൻ", "ആകെയുള്ളവൾ", "ആകെയുള്ളവൾക്ക്", "ആകുള്ളവൾക്ക്‌", "ഇത്", "ഇതിൽ", "ഇതിന്റെ", "ഇതും", "ഇതെല്ലാം",
    "ഇവ", "ഇവയിൽ", "ഇവയുടെ", "ഇവയും", "ഇവയെല്ലാം", "ഇവൻ", "ഇവൾ", "ഇവർ", "ഇവരുടെ", "ഇവരിൽ", "ഇവരെയും", "ഇവരെയെല്ലാം",
    "ഇവരോട്", "ഇവരോടും", "ഇവരോടുള്ള", "ഇവരോടുള്ളത്", "ഇവരോടുള്ളവ", "ഇവരോടുള്ളവർ", "ഇവരോടുള്ളവൻ", "ഇവരോടുള്ളവൾ",
    "ഇവരോടുള്ളവൾക്ക്", "ഇവരോടുള്ളവൾക്ക്‌"
]
def preprocess_malayalam_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ml")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ml"))
    tokens = [token for token in tokens if token not in stop]
    return ' '.join(tokens)
dataset_dfm['cleaned_transcript'] = dataset_dfm['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_dfm['encoded_label'] = label_encoder.fit_transform(dataset_dfm['class_label'])
label_encoder_path = "mal_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
# Out:
# Label encoder saved to mal_label_encoder.pkl

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train).toarray()
X_test_tfidf = tfidf_vectorizer.transform(X_test).toarray()
print(f"TF-IDF Vectorized Train Data Shape: {X_train_tfidf.shape}")
print(f"TF-IDF Vectorized Test Data Shape: {X_test_tfidf.shape}")
model = Sequential([
    Dense(256, input_dim=X_train_tfidf.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
history = model.fit(
    X_train_tfidf, y_train_cat,
    validation_data=(X_test_tfidf, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_tfidf, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_tfidf)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# TF-IDF Vectorized Train Data Shape: (411, 670)
# TF-IDF Vectorized Test Data Shape: (103, 670)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                      │ (None, 256)                 │         171,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 206,853 (808.02 KB)
#  Trainable params: 206,085 (805.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.2270 - loss: 2.7338 - val_accuracy: 0.5631 - val_loss: 1.5024
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3527 - loss: 2.2091 - val_accuracy: 0.5631 - val_loss: 1.4106
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4269 - loss: 1.6237 - val_accuracy: 0.5631 - val_loss: 1.3440
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5524 - loss: 1.1859 - val_accuracy: 0.5631 - val_loss: 1.2914
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6036 - loss: 1.1035 - val_accuracy: 0.5631 - val_loss: 1.2607
# Epoch 6/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6832 - loss: 0.8210 - val_accuracy: 0.5631 - val_loss: 1.2452
# Epoch 7/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7706 - loss: 0.6886 - val_accuracy: 0.5631 - val_loss: 1.2426
# Epoch 8/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7998 - loss: 0.6332 - val_accuracy: 0.5631 - val_loss: 1.2511
# Epoch 9/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8166 - loss: 0.5268 - val_accuracy: 0.5631 - val_loss: 1.2704
# Epoch 10/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8573 - loss: 0.4303 - val_accuracy: 0.5631 - val_loss: 1.3023
# Epoch 11/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8716 - loss: 0.3547 - val_accuracy: 0.5631 - val_loss: 1.3308
# Epoch 12/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8265 - loss: 0.4414 - val_accuracy: 0.5631 - val_loss: 1.3578
# Epoch 13/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9254 - loss: 0.2416 - val_accuracy: 0.5631 - val_loss: 1.3796
# Epoch 14/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9144 - loss: 0.2410 - val_accuracy: 0.5631 - val_loss: 1.4098
# Epoch 15/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9202 - loss: 0.2412 - val_accuracy: 0.5631 - val_loss: 1.4472
# Epoch 16/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9425 - loss: 0.1983 - val_accuracy: 0.5631 - val_loss: 1.4724
# Epoch 17/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9316 - loss: 0.2029 - val_accuracy: 0.5631 - val_loss: 1.4876
# Epoch 18/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9425 - loss: 0.1649 - val_accuracy: 0.5631 - val_loss: 1.5032
# Epoch 19/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9626 - loss: 0.1445 - val_accuracy: 0.5631 - val_loss: 1.5258
# Epoch 20/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9703 - loss: 0.1394 - val_accuracy: 0.5631 - val_loss: 1.5427
# Epoch 21/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9590 - loss: 0.1474 - val_accuracy: 0.5631 - val_loss: 1.5582
# Epoch 22/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9611 - loss: 0.1181 - val_accuracy: 0.5631 - val_loss: 1.5664
# Epoch 23/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9726 - loss: 0.1160 - val_accuracy: 0.5631 - val_loss: 1.5687
# Epoch 24/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9915 - loss: 0.0682 - val_accuracy: 0.5631 - val_loss: 1.5745
# Epoch 25/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9651 - loss: 0.0941 - val_accuracy: 0.5631 - val_loss: 1.5844
# Epoch 26/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9847 - loss: 0.0885 - val_accuracy: 0.5631 - val_loss: 1.6020
# Epoch 27/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9948 - loss: 0.0620 - val_accuracy: 0.5631 - val_loss: 1.6096
# Epoch 28/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9906 - loss: 0.0604 - val_accuracy: 0.5631 - val_loss: 1.6091
# Epoch 29/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9895 - loss: 0.0595 - val_accuracy: 0.5631 - val_loss: 1.6145
# Epoch 30/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9948 - loss: 0.0574 - val_accuracy: 0.5631 - val_loss: 1.6094
# Epoch 31/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9886 - loss: 0.0567 - val_accuracy: 0.5631 - val_loss: 1.6039
# Epoch 32/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9927 - loss: 0.0555 - val_accuracy: 0.5631 - val_loss: 1.5923
# Epoch 33/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9955 - loss: 0.0426 - val_accuracy: 0.5825 - val_loss: 1.5697
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9935 - loss: 0.0651 - val_accuracy: 0.5825 - val_loss: 1.5552
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9909 - loss: 0.0440 - val_accuracy: 0.5825 - val_loss: 1.5451
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5778 - loss: 1.6429
# Test Accuracy: 0.5825
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#               precision    recall  f1-score   support
#
#            C       0.50      0.12      0.20        16
#            G       0.00      0.00      0.00         9
#            N       0.59      1.00      0.74        58
#            P       0.00      0.00      0.00         8
#            R       0.00      0.00      0.00        12
#
#     accuracy                           0.58       103
#    macro avg       0.22      0.23      0.19       103
# weighted avg       0.41      0.58      0.45       103
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# TELUGU Adding TFIDFVectorizer

# %%
def load_dataset(base_dir='/content', lang='tel'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TE-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dft = load_dataset()

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['telugu']))
def preprocess_tel_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("te")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="te"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_dft['cleaned_transcript'] = dataset_dft['transcript'].apply(preprocess_tel_text)
label_encoder = LabelEncoder()
dataset_dft['encoded_label'] = label_encoder.fit_transform(dataset_dft['class_label'])
label_encoder_path = "tel_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
# Out:
# Label encoder saved to tel_label_encoder.pkl

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=5000)  
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train).toarray()
X_test_tfidf = tfidf_vectorizer.transform(X_test).toarray()
print(f"TF-IDF Vectorized Train Data Shape: {X_train_tfidf.shape}")
print(f"TF-IDF Vectorized Test Data Shape: {X_test_tfidf.shape}")
model = Sequential([
    Dense(256, input_dim=X_train_tfidf.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
history = model.fit(
    X_train_tfidf, y_train_cat,
    validation_data=(X_test_tfidf, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_tfidf, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_tfidf)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# TF-IDF Vectorized Train Data Shape: (411, 670)
# TF-IDF Vectorized Test Data Shape: (103, 670)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 256)                 │         171,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 206,853 (808.02 KB)
#  Trainable params: 206,085 (805.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - accuracy: 0.2206 - loss: 2.6080 - val_accuracy: 0.5534 - val_loss: 1.5713
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3192 - loss: 2.0895 - val_accuracy: 0.5631 - val_loss: 1.5296
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3814 - loss: 1.7429 - val_accuracy: 0.5631 - val_loss: 1.4944
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5303 - loss: 1.3517 - val_accuracy: 0.5631 - val_loss: 1.4597
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5376 - loss: 1.1478 - val_accuracy: 0.5631 - val_loss: 1.4268
# Epoch 6/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6762 - loss: 0.9587 - val_accuracy: 0.5631 - val_loss: 1.3898
# Epoch 7/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7470 - loss: 0.7141 - val_accuracy: 0.5631 - val_loss: 1.3589
# Epoch 8/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7416 - loss: 0.7066 - val_accuracy: 0.5631 - val_loss: 1.3300
# Epoch 9/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8091 - loss: 0.5433 - val_accuracy: 0.5631 - val_loss: 1.3027
# Epoch 10/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8289 - loss: 0.4901 - val_accuracy: 0.5631 - val_loss: 1.2746
# Epoch 11/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8635 - loss: 0.4133 - val_accuracy: 0.5631 - val_loss: 1.2558
# Epoch 12/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8868 - loss: 0.3790 - val_accuracy: 0.5631 - val_loss: 1.2407
# Epoch 13/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8961 - loss: 0.3326 - val_accuracy: 0.5631 - val_loss: 1.2262
# Epoch 14/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8980 - loss: 0.2839 - val_accuracy: 0.5631 - val_loss: 1.2157
# Epoch 15/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9376 - loss: 0.2308 - val_accuracy: 0.5631 - val_loss: 1.2094
# Epoch 16/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9132 - loss: 0.2576 - val_accuracy: 0.5631 - val_loss: 1.2062
# Epoch 17/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9622 - loss: 0.1880 - val_accuracy: 0.5631 - val_loss: 1.2009
# Epoch 18/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9479 - loss: 0.1600 - val_accuracy: 0.5631 - val_loss: 1.1941
# Epoch 19/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9372 - loss: 0.1715 - val_accuracy: 0.5631 - val_loss: 1.1894
# Epoch 20/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9578 - loss: 0.1585 - val_accuracy: 0.5631 - val_loss: 1.1873
# Epoch 21/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9791 - loss: 0.1098 - val_accuracy: 0.5631 - val_loss: 1.1825
# Epoch 22/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9658 - loss: 0.1290 - val_accuracy: 0.5631 - val_loss: 1.1825
# Epoch 23/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9559 - loss: 0.1570 - val_accuracy: 0.5728 - val_loss: 1.1806
# Epoch 24/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9705 - loss: 0.1000 - val_accuracy: 0.5728 - val_loss: 1.1751
# Epoch 25/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9791 - loss: 0.0905 - val_accuracy: 0.5728 - val_loss: 1.1725
# Epoch 26/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9818 - loss: 0.0830 - val_accuracy: 0.5825 - val_loss: 1.1721
# Epoch 27/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9700 - loss: 0.0851 - val_accuracy: 0.5922 - val_loss: 1.1738
# Epoch 28/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9796 - loss: 0.0657 - val_accuracy: 0.5922 - val_loss: 1.1807
# Epoch 29/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9936 - loss: 0.0485 - val_accuracy: 0.5728 - val_loss: 1.1803
# Epoch 30/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9691 - loss: 0.0938 - val_accuracy: 0.5825 - val_loss: 1.1753
# Epoch 31/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9971 - loss: 0.0414 - val_accuracy: 0.5922 - val_loss: 1.1764
# Epoch 32/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9716 - loss: 0.0672 - val_accuracy: 0.5922 - val_loss: 1.1847
# Epoch 33/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9941 - loss: 0.0376 - val_accuracy: 0.5922 - val_loss: 1.1876
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9934 - loss: 0.0397 - val_accuracy: 0.5922 - val_loss: 1.1942
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9820 - loss: 0.0620 - val_accuracy: 0.5825 - val_loss: 1.2072
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5747 - loss: 1.2491
# Test Accuracy: 0.5825
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#               precision    recall  f1-score   support
#
#            C       1.00      0.19      0.32        16
#            G       0.29      0.22      0.25         9
#            N       0.62      0.93      0.74        58
#            P       0.00      0.00      0.00         8
#            R       0.17      0.08      0.11        12
#
#     accuracy                           0.58       103
#    macro avg       0.41      0.28      0.28       103
# weighted avg       0.55      0.58      0.50       103
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# TAMIL Adding COUNT Vectorizer

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
def load_dataset(base_dir='/content', lang='tamil'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TA-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_df = load_dataset()
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['tamil']))
def preprocess_tamil_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ta")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ta"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_df['cleaned_transcript'] = dataset_df['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_df['encoded_label'] = label_encoder.fit_transform(dataset_df['class_label'])
label_encoder_path = "tamil_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
count_vectorizer = CountVectorizer(max_features=5000)  
X_train_count = count_vectorizer.fit_transform(X_train).toarray()
X_test_count = count_vectorizer.transform(X_test).toarray()
print(f"Count Vectorized Train Data Shape: {X_train_count.shape}")
print(f"Count Vectorized Test Data Shape: {X_test_count.shape}")
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_count.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(
    X_train_count, y_train_cat,
    validation_data=(X_test_count, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_count, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_count)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: advertools in /usr/local/lib/python3.11/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library)
# Epoch 27/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9730 - loss: 0.1062 - val_accuracy: 0.6214 - val_loss: 1.2478
# Epoch 28/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9587 - loss: 0.1484 - val_accuracy: 0.6214 - val_loss: 1.2659
# Epoch 29/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9565 - loss: 0.1379 - val_accuracy: 0.6117 - val_loss: 1.3040
# Epoch 30/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9625 - loss: 0.1278 - val_accuracy: 0.6117 - val_loss: 1.3170
# Epoch 31/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9816 - loss: 0.0898 - val_accuracy: 0.6019 - val_loss: 1.3254
# Epoch 32/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9531 - loss: 0.1245 - val_accuracy: 0.5922 - val_loss: 1.3242
# Epoch 33/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9885 - loss: 0.0703 - val_accuracy: 0.5922 - val_loss: 1.3377
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9700 - loss: 0.0882 - val_accuracy: 0.5825 - val_loss: 1.3562
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9789 - loss: 0.0754 - val_accuracy: 0.5922 - val_loss: 1.3742
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5713 - loss: 1.4163
# Test Accuracy: 0.5922
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#               precision    recall  f1-score   support
#
#            C       0.43      0.38      0.40        16
#            G       0.27      0.33      0.30         9
#            N       0.68      0.86      0.76        58
#            P       0.00      0.00      0.00         8
#            R       0.50      0.17      0.25        12
#
#     accuracy                           0.59       103
#    macro avg       0.38      0.35      0.34       103
# weighted avg       0.53      0.59      0.54       103
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# MALAYALAM Adding COUNT Vectorizer

# %%
def load_dataset(base_dir='/content', lang='mal'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "ML-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dfm = load_dataset()

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stop = [
    "അവൻ", "അവൾ", "അവർ", "ആ", "ആകാം", "ആകുന്നു", "ആകും", "ആകെയുള്ള", "ആകെയുള്ളത്", "ആകെയുള്ളവ", "ആകെയുള്ളവർ",
    "ആകെയുള്ളവൻ", "ആകെയുള്ളവൾ", "ആകെയുള്ളവൾക്ക്", "ആകുള്ളവൾക്ക്‌", "ഇത്", "ഇതിൽ", "ഇതിന്റെ", "ഇതും", "ഇതെല്ലാം",
    "ഇവ", "ഇവയിൽ", "ഇവയുടെ", "ഇവയും", "ഇവയെല്ലാം", "ഇവൻ", "ഇവൾ", "ഇവർ", "ഇവരുടെ", "ഇവരിൽ", "ഇവരെയും", "ഇവരെയെല്ലാം",
    "ഇവരോട്", "ഇവരോടും", "ഇവരോടുള്ള", "ഇവരോടുള്ളത്", "ഇവരോടുള്ളവ", "ഇവരോടുള്ളവർ", "ഇവരോടുള്ളവൻ", "ഇവരോടുള്ളവൾ",
    "ഇവരോടുള്ളവൾക്ക്", "ഇവരോടുള്ളവൾക്ക്‌"
]
def preprocess_malayalam_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ml")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ml"))
    tokens = [token for token in tokens if token not in stop]
    return ' '.join(tokens)
dataset_dfm['cleaned_transcript'] = dataset_dfm['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_dfm['encoded_label'] = label_encoder.fit_transform(dataset_dfm['class_label'])
label_encoder_path = "mal_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
# Out:
# Label encoder saved to mal_label_encoder.pkl

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer(max_features=5000)  
X_train_count = count_vectorizer.fit_transform(X_train).toarray()
X_test_count = count_vectorizer.transform(X_test).toarray()
print(f"Count Vectorized Train Data Shape: {X_train_count.shape}")
print(f"Count Vectorized Test Data Shape: {X_test_count.shape}")
model = Sequential([
    Dense(256, input_dim=X_train_count.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
history = model.fit(
    X_train_count, y_train_cat,
    validation_data=(X_test_count, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_count, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_count)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# Count Vectorized Train Data Shape: (411, 670)
# Count Vectorized Test Data Shape: (103, 670)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#               precision    recall  f1-score   support
#
#            C       0.38      0.19      0.25        16
#            G       0.24      0.44      0.31         9
#            N       0.68      0.88      0.77        58
#            P       0.00      0.00      0.00         8
#            R       0.67      0.17      0.27        12
#
#     accuracy                           0.58       103
#    macro avg       0.39      0.34      0.32       103
# weighted avg       0.54      0.58      0.53       103
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# TELUGU Adding COUNT Vectorizer

# %%
def load_dataset(base_dir='/content', lang='tel'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TE-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dft = load_dataset()

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['telugu']))
def preprocess_tel_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("te")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="te"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_dft['cleaned_transcript'] = dataset_dft['transcript'].apply(preprocess_tel_text)
label_encoder = LabelEncoder()
dataset_dft['encoded_label'] = label_encoder.fit_transform(dataset_dft['class_label'])
label_encoder_path = "tel_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
# Out:
# Label encoder saved to tel_label_encoder.pkl

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer(max_features=5000)  
X_train_count = count_vectorizer.fit_transform(X_train).toarray()
X_test_count = count_vectorizer.transform(X_test).toarray()
print(f"Count Vectorized Train Data Shape: {X_train_count.shape}")
print(f"Count Vectorized Test Data Shape: {X_test_count.shape}")
model = Sequential([
    Dense(256, input_dim=X_train_count.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
history = model.fit(
    X_train_count, y_train_cat,
    validation_data=(X_test_count, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_count, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_count)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# Count Vectorized Train Data Shape: (411, 670)
# Count Vectorized Test Data Shape: (103, 670)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                     │ (None, 256)                 │         171,776 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_14               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_15               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 206,853 (808.02 KB)
#  Trainable params: 206,085 (805.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.1520 - loss: 2.8512 - val_accuracy: 0.3010 - val_loss: 1.5810
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2717 - loss: 2.1983 - val_accuracy: 0.3204 - val_loss: 1.5433
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.3469 - loss: 1.8605 - val_accuracy: 0.3495 - val_loss: 1.5197
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4736 - loss: 1.3941 - val_accuracy: 0.3689 - val_loss: 1.4886
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5136 - loss: 1.3353 - val_accuracy: 0.4272 - val_loss: 1.4647
# Epoch 6/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.5806 - loss: 1.0836 - val_accuracy: 0.4660 - val_loss: 1.4257
# Epoch 7/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6321 - loss: 0.9953 - val_accuracy: 0.4951 - val_loss: 1.3992
# Epoch 8/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6428 - loss: 0.9194 - val_accuracy: 0.5243 - val_loss: 1.3701
# Epoch 9/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.7246 - loss: 0.7340 - val_accuracy: 0.5243 - val_loss: 1.3358
# Epoch 10/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7928 - loss: 0.6148 - val_accuracy: 0.5243 - val_loss: 1.3092
# Epoch 11/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8320 - loss: 0.5209 - val_accuracy: 0.5631 - val_loss: 1.2771
# Epoch 12/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8638 - loss: 0.4620 - val_accuracy: 0.5825 - val_loss: 1.2520
# Epoch 13/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8418 - loss: 0.4851 - val_accuracy: 0.5922 - val_loss: 1.2262
# Epoch 14/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8475 - loss: 0.4028 - val_accuracy: 0.6117 - val_loss: 1.2150
# Epoch 15/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8924 - loss: 0.3729 - val_accuracy: 0.5922 - val_loss: 1.1947
# Epoch 16/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8929 - loss: 0.3304 - val_accuracy: 0.5922 - val_loss: 1.1817
# Epoch 17/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8952 - loss: 0.3179 - val_accuracy: 0.6019 - val_loss: 1.1728
# Epoch 18/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9054 - loss: 0.2830 - val_accuracy: 0.6019 - val_loss: 1.1664
# Epoch 19/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9073 - loss: 0.2924 - val_accuracy: 0.6019 - val_loss: 1.1510
# Epoch 20/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9180 - loss: 0.2577 - val_accuracy: 0.6214 - val_loss: 1.1404
# Epoch 21/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9215 - loss: 0.2398 - val_accuracy: 0.6214 - val_loss: 1.1413
# Epoch 22/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9275 - loss: 0.2211 - val_accuracy: 0.5922 - val_loss: 1.1407
# Epoch 23/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9471 - loss: 0.1849 - val_accuracy: 0.5922 - val_loss: 1.1436
# Epoch 24/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9381 - loss: 0.2054 - val_accuracy: 0.6019 - val_loss: 1.1521
# Epoch 25/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9777 - loss: 0.1254 - val_accuracy: 0.6019 - val_loss: 1.1596
# Epoch 26/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9597 - loss: 0.1454 - val_accuracy: 0.6019 - val_loss: 1.1599
# Epoch 27/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9508 - loss: 0.1473 - val_accuracy: 0.6117 - val_loss: 1.1654
# Epoch 28/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9749 - loss: 0.1131 - val_accuracy: 0.6117 - val_loss: 1.1827
# Epoch 29/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9608 - loss: 0.1375 - val_accuracy: 0.6019 - val_loss: 1.1998
# Epoch 30/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9818 - loss: 0.0929 - val_accuracy: 0.5922 - val_loss: 1.2169
# Epoch 31/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9637 - loss: 0.1273 - val_accuracy: 0.5922 - val_loss: 1.2286
# Epoch 32/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9931 - loss: 0.0691 - val_accuracy: 0.5825 - val_loss: 1.2456
# Epoch 33/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9744 - loss: 0.1095 - val_accuracy: 0.5825 - val_loss: 1.2642
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9734 - loss: 0.0972 - val_accuracy: 0.5922 - val_loss: 1.2924
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9663 - loss: 0.0980 - val_accuracy: 0.6019 - val_loss: 1.2887
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6179 - loss: 1.2820
# Test Accuracy: 0.6019
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#               precision    recall  f1-score   support
#
#            C       0.50      0.38      0.43        16
#            G       0.19      0.33      0.24         9
#            N       0.70      0.83      0.76        58
#            P       0.00      0.00      0.00         8
#            R       0.83      0.42      0.56        12
#
#     accuracy                           0.60       103
#    macro avg       0.44      0.39      0.40       103
# weighted avg       0.58      0.60      0.58       103
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# TAMIL *xlm-roberta-base*

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModel
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
def load_dataset(base_dir='/content', lang='tamil'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TA-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_df = load_dataset()
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['tamil']))
def preprocess_tamil_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ta")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ta"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_df['cleaned_transcript'] = dataset_df['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_df['encoded_label'] = label_encoder.fit_transform(dataset_df['class_label'])
label_encoder_path = "tamil_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
def extract_embeddings_xlmr(model_name, texts):
    """Extract embeddings for the given texts using a pre-trained XLM-RoBERTa model."""
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i + batch_size]
            encoded_inputs = tokenizer(
                batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt"
            )
            encoded_inputs = {key: tensor.to(device) for key, tensor in encoded_inputs.items()}
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
X_train_embeddings = extract_embeddings_xlmr("xlm-roberta-base", X_train.tolist())
X_test_embeddings = extract_embeddings_xlmr("xlm-roberta-base", X_test.tolist())
print(f"XLM-RoBERTa Train Embeddings Shape: {X_train_embeddings.shape}")
print(f"XLM-RoBERTa Test Embeddings Shape: {X_test_embeddings.shape}")
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_embeddings.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(
    X_train_embeddings, y_train_cat,
    validation_data=(X_test_embeddings, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_embeddings, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_embeddings)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.47.1)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.11/dist-packages (0.92)
# Requirement already satisfied: advertools in /usr/local/lib/python3.11/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (3.0.2)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.2)
# Requirement already satisfied: pyasn1>=0.4 in /usr/local/lib/python3.11/dist-packages (from advertools) (0.6.1)
# Requirement already satisfied: scrapy>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (2.12.0)
# Requirement already satisfied: twython>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (3.9.1)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from advertools) (17.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: Twisted>=21.7.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.11.0)
# Requirement already satisfied: cryptography>=37.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (43.0.3)
# Requirement already satisfied: cssselect>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.10.0)
# Requirement already satisfied: pyOpenSSL>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (1.7.0)
# Requirement already satisfied: service-identity>=18.1.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (24.2.0)
# Requirement already satisfied: w3lib>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (2.2.1)
# Requirement already satisfied: zope.interface>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (7.2)
# Requirement already satisfied: protego>=0.1.15 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (0.4.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (0.10.0)
# Requirement already satisfied: tldextract in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (5.1.3)
# Requirement already satisfied: lxml>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (5.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (0.7.1)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /usr/local/lib/python3.11/dist-packages (from scrapy>=2.5.0->advertools) (2.0.7)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from twython>=3.8.0->advertools) (1.3.1)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.1.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (4.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=37.0.0->scrapy>=2.5.0->advertools) (1.17.1)
# Requirement already satisfied: jmespath>=0.9.5 in /usr/local/lib/python3.11/dist-packages (
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9105 - loss: 0.2385 - val_accuracy: 0.6699 - val_loss: 0.9262
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9262 - loss: 0.2040 - val_accuracy: 0.7282 - val_loss: 0.9067
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7215 - loss: 0.8901
# Test Accuracy: 0.7282
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#               precision    recall  f1-score   support
#
#            C       0.46      0.75      0.57        16
#            G       1.00      0.33      0.50         9
#            N       0.84      0.84      0.84        58
#            P       1.00      0.25      0.40         8
#            R       0.64      0.75      0.69        12
#
#     accuracy                           0.73       103
#    macro avg       0.79      0.59      0.60       103
# weighted avg       0.79      0.73      0.72       103

# %% [markdown]
# TELUGU *xlm-roberta-base*

# %%
import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from transformers import AutoTokenizer, AutoModel
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
def load_dataset(base_dir='/content', lang='tel'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "TE-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dft = load_dataset()
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stopwords = list(sorted(adv.stopwords['telugu']))
def preprocess_tel_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("te")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="te"))
    tokens = [token for token in tokens if token not in stopwords]
    return ' '.join(tokens)
dataset_dft['cleaned_transcript'] = dataset_dft['transcript'].apply(preprocess_tel_text)
label_encoder = LabelEncoder()
dataset_dft['encoded_label'] = label_encoder.fit_transform(dataset_dft['class_label'])
label_encoder_path = "tel_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
def extract_embeddings_exbert(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i + batch_size]
            encoded_inputs = tokenizer(
                batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt"
            )
            encoded_inputs = {key: tensor.to(device) for key, tensor in encoded_inputs.items()}
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
X_train_embeddings = extract_embeddings_xlmr("xlm-roberta-base", X_train.tolist())
X_test_embeddings = extract_embeddings_xlmr("xlm-roberta-base", X_test.tolist())
print(f"XLM-RoBERTa Train Embeddings Shape: {X_train_embeddings.shape}")
print(f"XLM-RoBERTa Test Embeddings Shape: {X_test_embeddings.shape}")
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_embeddings.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(
    X_train_embeddings, y_train_cat,
    validation_data=(X_test_embeddings, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_embeddings, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_embeddings)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# Using device: cpu
# Label encoder saved to tel_label_encoder.pkl
# XLM-RoBERTa Train Embeddings Shape: (411, 768)
# XLM-RoBERTa Test Embeddings Shape: (103, 768)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 231,941 (906.02 KB)
#  Trainable params: 231,173 (903.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.3261 - loss: 2.3492 - val_accuracy: 0.1553 - val_loss: 2.3514
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4004 - loss: 1.8629 - val_accuracy: 0.1553 - val_loss: 2.1389
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5182 - loss: 1.5583 - val_accuracy: 0.1553 - val_loss: 1.9581
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5802 - loss: 1.3393 - val_accuracy: 0.1553 - val_loss: 1.7831
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5748 - loss: 1.2853 - val_accuracy: 0.1553 - val_loss: 1.6198
# Epoch 6/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6159 - loss: 1.1657 - val_accuracy: 0.1650 - val_loss: 1.5153
# Epoch 7/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6708 - loss: 0.9989 - val_accuracy: 0.3981 - val_loss: 1.3962
# Epoch 8/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6714 - loss: 0.9849 - val_accuracy: 0.6117 - val_loss: 1.2810
# Epoch 9/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6975 - loss: 0.8628 - val_accuracy: 0.6117 - val_loss: 1.1884
# Epoch 10/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7229 - loss: 0.8430 - val_accuracy: 0.5728 - val_loss: 1.1596
# Epoch 11/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7393 - loss: 0.7116 - val_accuracy: 0.6117 - val_loss: 1.1153
# Epoch 12/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7633 - loss: 0.7931 - val_accuracy: 0.6117 - val_loss: 1.0701
# Epoch 13/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7864 - loss: 0.6037 - val_accuracy: 0.5922 - val_loss: 1.0513
# Epoch 14/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8108 - loss: 0.5012 - val_accuracy: 0.5728 - val_loss: 1.0476
# Epoch 15/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7736 - loss: 0.6807 - val_accuracy: 0.6117 - val_loss: 1.0120
# Epoch 16/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8070 - loss: 0.5285 - val_accuracy: 0.6019 - val_loss: 0.9944
# Epoch 17/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8125 - loss: 0.5963 - val_accuracy: 0.5922 - val_loss: 1.0091
# Epoch 18/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8066 - loss: 0.5775 - val_accuracy: 0.6214 - val_loss: 0.9604
# Epoch 19/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7990 - loss: 0.5131 - val_accuracy: 0.6019 - val_loss: 0.9521
# Epoch 20/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8412 - loss: 0.4842 - val_accuracy: 0.6117 - val_loss: 0.9158
# Epoch 21/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8341 - loss: 0.4142 - val_accuracy: 0.6019 - val_loss: 1.0029
# Epoch 22/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8840 - loss: 0.3864 - val_accuracy: 0.6019 - val_loss: 0.9782
# Epoch 23/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8359 - loss: 0.4736 - val_accuracy: 0.6214 - val_loss: 1.0352
# Epoch 24/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8850 - loss: 0.3166 - val_accuracy: 0.6505 - val_loss: 0.8418
# Epoch 25/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8879 - loss: 0.3534 - val_accuracy: 0.6214 - val_loss: 1.0489
# Epoch 26/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8510 - loss: 0.4697 - val_accuracy: 0.6408 - val_loss: 0.9942
# Epoch 27/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8753 - loss: 0.3237 - val_accuracy: 0.6505 - val_loss: 0.8120
# Epoch 28/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8715 - loss: 0.3676 - val_accuracy: 0.6602 - val_loss: 0.8810
# Epoch 29/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9030 - loss: 0.2982 - val_accuracy: 0.6796 - val_loss: 0.8669
# Epoch 30/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8852 - loss: 0.3301 - val_accuracy: 0.6796 - val_loss: 0.7787
# Epoch 31/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9051 - loss: 0.2897 - val_accuracy: 0.6505 - val_loss: 1.0056
# Epoch 32/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8882 - loss: 0.3178 - val_accuracy: 0.6602 - val_loss: 1.0530
# Epoch 33/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9177 - loss: 0.2693 - val_accuracy: 0.7087 - val_loss: 0.7557
# Epoch 34/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8978 - loss: 0.2735 - val_accuracy: 0.6602 - val_loss: 0.8109
# Epoch 35/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9085 - loss: 0.2254 - val_accuracy: 0.7087 - val_loss: 0.8591
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7408 - loss: 0.8799
# Test Accuracy: 0.7087
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
#               precision    recall  f1-score   support
#
#            C       0.57      0.25      0.35        16
#            G       0.43      0.67      0.52         9
#            N       0.77      0.93      0.84        58
#            P       1.00      0.38      0.55         8
#            R       0.67      0.50      0.57        12
#
#     accuracy                           0.71       103
#    macro avg       0.69      0.54      0.57       103
# weighted avg       0.72      0.71      0.68       103

# %% [markdown]
# MALAYALAM *xlm-roberta-base*

# %%
def load_dataset(base_dir='/content', lang='mal'):
    dataset = []
    text_file = os.path.join(base_dir, lang, "text", "ML-AT-train.xlsx")
    text_df = pd.read_excel(text_file)
    for _, row in text_df.iterrows():
        metadata = {"class_label": row["Class Label Short"], "gender": "Unknown"}  
        dataset.append({
            "audio_path": "Nil",  
            "transcript": row["Transcript"],
            "class_label": metadata["class_label"],
            "gender": metadata["gender"]
        })
    return pd.DataFrame(dataset)
dataset_dfm = load_dataset()

# %%
from indicnlp.tokenize import indic_tokenize
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
import advertools as adv
import pickle
stop = [
    "അവൻ", "അവൾ", "അവർ", "ആ", "ആകാം", "ആകുന്നു", "ആകും", "ആകെയുള്ള", "ആകെയുള്ളത്", "ആകെയുള്ളവ", "ആകെയുള്ളവർ",
    "ആകെയുള്ളവൻ", "ആകെയുള്ളവൾ", "ആകെയുള്ളവൾക്ക്", "ആകുള്ളവൾക്ക്‌", "ഇത്", "ഇതിൽ", "ഇതിന്റെ", "ഇതും", "ഇതെല്ലാം",
    "ഇവ", "ഇവയിൽ", "ഇവയുടെ", "ഇവയും", "ഇവയെല്ലാം", "ഇവൻ", "ഇവൾ", "ഇവർ", "ഇവരുടെ", "ഇവരിൽ", "ഇവരെയും", "ഇവരെയെല്ലാം",
    "ഇവരോട്", "ഇവരോടും", "ഇവരോടുള്ള", "ഇവരോടുള്ളത്", "ഇവരോടുള്ളവ", "ഇവരോടുള്ളവർ", "ഇവരോടുള്ളവൻ", "ഇവരോടുള്ളവൾ",
    "ഇവരോടുള്ളവൾക്ക്", "ഇവരോടുള്ളവൾക്ക്‌"
]
def preprocess_malayalam_text(text):
    normalizer_factory = IndicNormalizerFactory()
    normalizer = normalizer_factory.get_normalizer("ml")
    text = normalizer.normalize(text)
    tokens = list(indic_tokenize.trivial_tokenize(text, lang="ml"))
    tokens = [token for token in tokens if token not in stop]
    return ' '.join(tokens)
dataset_dfm['cleaned_transcript'] = dataset_dfm['transcript'].apply(preprocess_tamil_text)
label_encoder = LabelEncoder()
dataset_dfm['encoded_label'] = label_encoder.fit_transform(dataset_dfm['class_label'])
label_encoder_path = "mal_label_encoder.pkl"
with open(label_encoder_path, "wb") as f:
    pickle.dump(label_encoder, f)
print(f"Label encoder saved to {label_encoder_path}")
# Out:
# Label encoder saved to mal_label_encoder.pkl

# %%
X_train, X_test, y_train, y_test = train_test_split(
    dataset_df['cleaned_transcript'], dataset_df['encoded_label'], test_size=0.2, random_state=42
)
def extract_embeddings_exbert(model_name, texts):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name).to(device)
    model.eval()
    embeddings = []
    batch_size = 16
    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i + batch_size]
            encoded_inputs = tokenizer(
                batch_texts, padding=True, truncation=True, max_length=128, return_tensors="pt"
            )
            encoded_inputs = {key: tensor.to(device) for key, tensor in encoded_inputs.items()}
            outputs = model(**encoded_inputs)
            batch_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
            embeddings.extend(batch_embeddings)
    return np.array(embeddings)
X_train_embeddings = extract_embeddings_xlmr("xlm-roberta-base", X_train.tolist())
X_test_embeddings = extract_embeddings_xlmr("xlm-roberta-base", X_test.tolist())
print(f"XLM-RoBERTa Train Embeddings Shape: {X_train_embeddings.shape}")
print(f"XLM-RoBERTa Test Embeddings Shape: {X_test_embeddings.shape}")
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
model = Sequential([
    Dense(256, input_dim=X_train_embeddings.shape[1], activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(len(label_encoder.classes_), activation='softmax')
])
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(
    X_train_embeddings, y_train_cat,
    validation_data=(X_test_embeddings, y_test_cat),
    epochs=35, batch_size=32
)
loss, accuracy = model.evaluate(X_test_embeddings, y_test_cat)
print(f"Test Accuracy: {accuracy:.4f}")
y_pred = model.predict(X_test_embeddings)
y_pred_labels = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_labels, target_names=label_encoder.classes_))
# Out:
# XLM-RoBERTa Train Embeddings Shape: (411, 768)
# XLM-RoBERTa Test Embeddings Shape: (103, 768)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 256)                 │         196,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 231,941 (906.02 KB)
#  Trainable params: 231,173 (903.02 KB)
#  Non-trainable params: 768 (3.00 KB)
# Epoch 1/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.2266 - loss: 2.4651 - val_accuracy: 0.1165 - val_loss: 2.0876
# Epoch 2/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3862 - loss: 1.8828 - val_accuracy: 0.1165 - val_loss: 1.9873
# Epoch 3/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4516 - loss: 1.6964 - val_accuracy: 0.1165 - val_loss: 1.9304
# Epoch 4/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5607 - loss: 1.3897 - val_accuracy: 0.1359 - val_loss: 1.8189
# Epoch 5/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5974 - loss: 1.3386 - val_accuracy: 0.1359 - val_loss: 1.6918
# Epoch 6/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6002 - loss: 1.1645 - val_accuracy: 0.1359 - val_loss: 1.6527
# Epoch 7/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6541 - loss: 1.0714 - val_accuracy: 0.1942 - val_loss: 1.5333
# Epoch 8/35
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.